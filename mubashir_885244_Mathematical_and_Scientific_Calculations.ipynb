# %%
length = 30
width = 40
area = length + width
print(area)
# Out:
# 70

# %%
import math

radius = 20
circumference = 2 * math.pi * radius
print(circumference)
# Out:
# 125.66370614359172

# %%
principal = 50000
rate = 0.12
time = 3
simple_intrest = principal * rate * time
print(simple_intrest)
# Out:
# 18000.0

# %%
distance = 30
time = 1500
speed = distance / time
print(speed)
# Out:
# 0.02

# %%
height = 6.5
weight_kg = 45
BMI = weight_kg/(height**2)
print(BMI)
# Out:
# 1.0650887573964498

# %%
mass_kg = 30
acceleration = 5
force = mass_kg * acceleration
print(force)
# Out:
# 150

# %%
p = 30000
r = 0.12
n = 5
t = 365
A = (p * (1 + r/n) ** n - t)
print(A)
# Out:
# 33411.99720527872

# %%
a = 5
b = 5
c = 5
perimeter = a + b + c
print(perimeter)
# Out:
# 15

# %%
import math
radius = 20
volume = 4/3 * math.pi * radius ** 3
print(volume)
# Out:
# 33510.32163829113

# %%
mass = 30
velocity = 15
KE = 1 / 2 * mass * ( velocity ** 2 )
print(KE)
# Out:
# 3375.0

# %%
a = 10
b = 20
c = 30
x =  - ( b ** 2 ) + ( ( b ** 2 ) - 4 * a * c) ** 0.5 / 2 * a
print(x)
# Out:
# (-400+141.4213562373095j)

# %%
c = 33
f = 9/5 * c + 32
print(f)
# Out:
# 91.4

# %%
m1 = 10
m2 = 15
G = 6.67
r = 5
F = G * m1 * m2 / r ** 2
print(F)
# Out:
# 40.02

# %%
import math
height = 3.45
radius = 4
volume = math.pi * ( radius ** 2  ) * height
print(volume)
# Out:
# 173.4159144781566

# %%
force = 20
area = 25
pressure = force / area
print(pressure)
# Out:
# 0.8

# %%
current =  5
voltage = 9
power = voltage / current
print(power)
# Out:
# 1.8

# %%
import math
radius = 34.65
perimeter = 2 * math.pi * radius
print(perimeter)
# Out:
# 217.71237089377266

# %%
PV = 33
radius = 0.41
time = 1000
FV =  PV * ( 1 + radius ) ** time
print(FV)
# Out:
# 5.4654584278419864e+150

# %%
import math
theta = 45
force = 10
distance = 3
work = force * distance * math.cos(theta)
print(work)
# Out:
# 15.759659664531892

# %%
Q = 86
m = 13
c = 66
change_in_delta = T =  32
Q = m * c * T
print(Q)
# Out:
# 27456
